# %%
import pandas as pd

# %%
from fuzzywuzzy import process
import numpy as np

ffpe_dat = pd.read_excel('D:\\Shweta\\ffpe_db_column_entries\\2021_01_25_PCCM_FFPE_1_672_values.xlsx')
defined_voc = pd.read_excel('D:\\Shweta\\ffpe_db_column_entries\\defined_vocab.xlsx')


ffpe_dat['all_values'] = ffpe_dat[ffpe_dat.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)), axis = 1)


defined_voc['all_vocab'] = defined_voc[defined_voc.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)), axis = 1)


ffpe_voc_dat = ffpe_dat[['col names', 'all_values']]
defined_voc_dat = defined_voc[['col names', 'all_vocab']]

ffpe_voc_dat = ffpe_voc_dat.rename(columns = {'col names' : 'ffpe_col_names',
                               'all_values' : 'ffpe_unique_values'})

defined_voc_dat = defined_voc_dat.rename(columns = {'col names' : 'vocab_col_names',
                                                'all_vocab': 'def_vocab_values'})

vocab = pd.concat([ffpe_voc_dat, defined_voc_dat], axis = 1)

# %%
ffpe_voc_dat.head()
# Out:
#             ffpe_col_names                                 ffpe_unique_values
# 0              fnac_breast  fnac_breast_no,fnac_breast_yes,requires follow...
# 1              fnac_breast  fnac_breast_no,fnac_breast_yes,requires follow...
# 2            fnac_slide_id  76-18,556-15,data not in report,153-16,515-16,...
# 3           fnac_diagnosis  negative for malignant cells,fibroadenoma,data...
# 4  fnac_diagnosis_comments  paucicellular,data not in report,15-08(slide),...

# %%
defined_voc_dat.head()
# Out:
#                   vocab_col_names  \
# 0                     fnac_breast
# 1              review_fnac_breast
# 2           review_fnac_diagnosis
# 3  review_fnac_diagnosis_comments
# 4               reason_for_biopsy
#
#                                     def_vocab_values
# 0  fnac_breast_no,fnac_breast_yes,fnac_breast_req...
# 1  review_fnac_breast_no,review_fnac_breast_yes,r...
# 2                                          free text
# 3                                          free text
# 4  diagnostic,recurrence diagnosis,follow up diag...

# %%
vocab.head()
# Out:
#             ffpe_col_names                                 ffpe_unique_values  \
# 0              fnac_breast  fnac_breast_no,fnac_breast_yes,requires follow...
# 1              fnac_breast  fnac_breast_no,fnac_breast_yes,requires follow...
# 2            fnac_slide_id  76-18,556-15,data not in report,153-16,515-16,...
# 3           fnac_diagnosis  negative for malignant cells,fibroadenoma,data...
# 4  fnac_diagnosis_comments  paucicellular,data not in report,15-08(slide),...
#
#                   vocab_col_names  \
# 0                     fnac_breast
# 1              review_fnac_breast
# 2           review_fnac_diagnosis
# 3  review_fnac_diagnosis_comments
# 4               reason_for_biopsy
#
#                                     def_vocab_values
# 0  fnac_breast_no,fnac_breast_yes,fnac_breast_req...
# 1  review_fnac_breast_no,review_fnac_breast_yes,r...
# 2                                          free text
# 3                                          free text
# 4  diagnostic,recurrence diagnosis,follow up diag...

# %%
defined_voc_dat['vocab_col_names']
# Out:
# 0                                            fnac_breast
# 1                                     review_fnac_breast
# 2                                  review_fnac_diagnosis
# 3                         review_fnac_diagnosis_comments
# 4                                      reason_for_biopsy
#                              ...
# 167                                             act drug
# 168                                   additional comment
# 169               file cross checked with rituja/madhura
# 170    blocks out to patient's/clinical staff/patient...
# 171                                             given by
# Name: vocab_col_names, Length: 172, dtype: object

# %%
ffpe_voc_dat['ffpe_col_names']
# Out:
# 0                                            fnac_breast
# 1                                            fnac_breast
# 2                                          fnac_slide_id
# 3                                         fnac_diagnosis
# 4                                fnac_diagnosis_comments
#                              ...
# 188                review_surgery_clinical_stage_compute
# 189                                     act taken yes/no
# 190                                             act drug
# 191                                   additional comment
# 192    blocks out to patient's/clinical staff/patient...
# Name: ffpe_col_names, Length: 193, dtype: object

# %%
ffpe_voc_dat.rename(columns = ['ffpe_col_names': 'col_name'])
defined_voc_dat.rename(columns = ['vocab_col_names': 'col_name'])
# Out:
#   File "<ipython-input-9-b48ccb3a3217>", line 1
#     ffpe_voc_dat.rename(columns = ['ffpe_col_names': 'col_name'])
#                                                    ^
# SyntaxError: invalid syntax

# %%
ffpe_voc_dat = ffpe_voc_dat.rename(columns = {'ffpe_col_names': 'col_name'})
defined_voc_dat = defined_voc_dat.rename(columns = {'vocab_col_names': 'col_name'})

# %%
vocab = ffpe_voc_dat.merge(defined_voc_dat, on='col_name')

# %%
vocab.head()
# Out:
#                          col_name  \
# 0                     fnac_breast
# 1                     fnac_breast
# 2              review_fnac_breast
# 3           review_fnac_diagnosis
# 4  review_fnac_diagnosis_comments
#
#                                   ffpe_unique_values  \
# 0  fnac_breast_no,fnac_breast_yes,requires follow...
# 1  fnac_breast_no,fnac_breast_yes,requires follow...
# 2  review_fnac_breast_no,fnac_breast_yes,review_f...
# 3  suspcious of malignancy,0,positive for maligna...
# 4  received 4 stained slides labelled c514/05,nav...
#
#                                     def_vocab_values
# 0  fnac_breast_no,fnac_breast_yes,fnac_breast_req...
# 1  fnac_breast_no,fnac_breast_yes,fnac_breast_req...
# 2  review_fnac_breast_no,review_fnac_breast_yes,r...
# 3                                          free text
# 4                                          free text

# %%
print(vocab.shape, defined_voc_dat.shape, ffpe_voc_dat.shape)
# Out:
# (146, 3) (172, 2) (193, 2)

# %%
# def clean_names(df, name_str):
#     cleaned_names = []
#     for name in df[name_str]:
#         clean_name = str(name).lower()
#         cleaned_names.append(clean_name)
#     return cleaned_names

# %%
# ffpe_clean_names = clean_names(vocab, 'col_name')
# ffpe_clean_names[1:10], len(ffpe_clean_names)
# Out:
# (['fnac_breast',
#   'review_fnac_breast',
#   'review_fnac_diagnosis',
#   'review_fnac_diagnosis_comments',
#   'reason_for_biopsy',
#   'biopsy_site',
#   'biopsy_report in pccm custody',
#   'biopsy_ihc_report in pccm custody',
#   'biospy_block_source'],
#  146)

# %%
# voc_clean_names = clean_names(vocab, 'col_name')

# %%
def split_the_column_entries(df, name_str):
    lst = []
    for value in df[name_str]:
        clean_value = str(value).split(',')
        lst.append(clean_value)
    return lst

# %%
ffpe_value_split = split_the_column_entries(vocab, 'ffpe_unique_values') 
ffpe_value_split[0:3] , len(ffpe_value_split)
# Out:
# ([['fnac_breast_no',
#    'fnac_breast_yes',
#    'requires follow up',
#    'benign',
#    'fnac_breast_na',
#    'duct carcinoma',
#    'fnac_breast_left',
#    'negative for atypical or malignant cells'],
#   ['fnac_breast_no',
#    'fnac_breast_yes',
#    'requires follow up',
#    'benign',
#    'fnac_breast_na',
#    'duct carcinoma',
#    'fnac_breast_left',
#    'negative for atypical or malignant cells'],
#   ['review_fnac_breast_no',
#    'fnac_breast_yes',
#    'review_fnac_breast_yes',
#    'nav',
#    'intraductal papillary tumour']],
#  146)

# %%
voc_value_split = split_the_column_entries(vocab, 'def_vocab_values')
voc_value_split[0:3] , len(voc_value_split)
# Out:
# ([['fnac_breast_no', 'fnac_breast_yes', 'fnac_breast_requires follow up'],
#   ['fnac_breast_no', 'fnac_breast_yes', 'fnac_breast_requires follow up'],
#   ['review_fnac_breast_no',
#    'review_fnac_breast_yes',
#    'review_fnac_breast_requires follow up']],
#  146)

# %%
set(ffpe_value_split[0]) - set(voc_value_split[0])
# Out:
# {'benign',
#  'duct carcinoma',
#  'fnac_breast_left',
#  'fnac_breast_na',
#  'negative for atypical or malignant cells',
#  'requires follow up'}

# %%
for val1 in ffpe_value_split:
    for val2 in voc_value_split:
        lst = list(set(val1) - set(val2))
        print(lst)
# Out:
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'negative for atypical or malignant cells', 'duct carcinoma']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'negative for atypical or malignant cells', 'duct carcinoma']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'negative for atypical or malignant cells', 'duct carcinoma']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'negative for atypical or malignant cells', 'duct carcinoma']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'benign', 'fnac_breast_left', 'fnac_breast_yes', 'negative for atypical or malignant cells', 'duct carcinoma', 'fnac_breast_no']
# ['fnac_breast_na', 'requires follow up', 'benign', 'duct carcinoma', 'fnac_breast_left', 'negative for atypical or malignant cells', 'fnac_breast_yes', 'fnac_breast_no']
# ...
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", 'not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'tumour_biopsy_pr_percent_na', '0.05', '3', 'rb: na; lb: dcis_biopsy_seen', 'dcis_biopsy_lt: seen; rt: not seen', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen', 'rt breast and lt breast: dcis_biopsy_seen', '0', 'dcis_biopsy_not mentioned in report', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', 'rb:dcis_biopsy_data not in report; lb: seen', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', 'rb: dcis_biopsy_not mentioned in report']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# ['rt breast and lt breast: dcis_biopsy_seen', 'dcis_biopsy_data not in report', "9 o'clock:dcis_biopsy_not seen", '0', 'not mentioned in report', 'dcis_biopsy_not mentioned in report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_seen', 'dcis_biopsy_na', 'rb:dcis_biopsy_seen;lb:dcis_biopsy_seen', 'dcis_biopsy_seen', '1945: dcis_biopsy_not seen; 1947:dcis_biopsy_not seen', 'not mentioned in  report', 'rb: dcis_biopsy_data not in report; lb: dcis_biopsy_data not in report', 'rt breast: na; lt breast: dcis_biopsy_data not in report', 'tumour_biopsy_pr_percent_na', '0.05', 'dcis_biopsy_data not in report; dcis_biopsy_seen', 'nav', '3', 'rb: na; lb: dcis_biopsy_seen', 'rb: dcis_biopsy_not mentioned in report', 'rb:dcis_biopsy_data not in report; lb: seen', 'dcis_biopsy_lt: seen; rt: not seen', 'requires follow up', "8 o' clock lesion: dcis_biopsy_seen; 10 o' clock lesion: dcis_biopsy_seen", 'dcis_biopsy_no', "4 o'clock lesion: dcis_biopsy_not seen; 7 o'clock lesion: dcis_biopsy_seen", 'dcis_biopsy_not seen']
# [' mononulcear cells infiltration', 'no', 'data not curated', 'tumour_biopsy_her2_not done', 'yes', ' lymphoplasmacytic cells infiltration', 'tumour_biopsy_her2_negative', ' mononuclear cells infiltration']
# [' mononulcear cells infiltration', 'no', 'data not curated', 'tumour_biopsy_her2_not done', 'yes', ' lymphoplasmacytic cells infiltration', 'tumour_biopsy_her2_negative', ' mononuclear cells infiltration']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
lst = []
for i in range(len(ffpe_value_split)):
    lst_var = list(set(ffpe_value_split[i])-set(voc_value_split[i]))
    lst.append(lst_var)
len(lst)
# Out:
# 146

# %%
def remove_vocab_from_ffpe_values(df, ffpe_val_str='ffpe_unique_values', voc_val_str='def_vocab_values'):
    ffpe_value_split = split_the_column_entries(df, ffpe_val_str)
    voc_value_split = split_the_column_entries(df, voc_val_str)
    lst = []
    for i in range(len(ffpe_value_split)):
        lst_var = list(set(ffpe_value_split[i])-set(voc_value_split[i]))
        lst.append(lst_var)
    return lst

# %%
def remove_vocab_from_ffpe_values(df, ffpe_val_str='ffpe_unique_values', voc_val_str='def_vocab_values'):
    ffpe_value_split = split_the_column_entries(df, ffpe_val_str)
    voc_value_split = split_the_column_entries(df, voc_val_str)
    lst = [] 
    for i in range(len(ffpe_value_split)):
        lst_var = list(set(ffpe_value_split[i])-set(voc_value_split[i]))
        lst.append(lst_var)
        d = pd.DataFrame(lst)
    return d

# %%
# def remove_vocab_from_ffpe_values(df, ffpe_val_str='ffpe_unique_values', voc_val_str='def_vocab_values'):
#     ffpe_value_split = split_the_column_entries(df, ffpe_val_str)
#     voc_value_split = split_the_column_entries(df, voc_val_str)
#     removed_voc_lst = []  
#     for val1 in ffpe_value_split:
#         for val2 in voc_value_split:
#             lst = list(set(val1) - set(val2))
#             removed_voc_lst.append(lst)
#     return removed_voc_lst

# %%
lst_d = remove_vocab_from_ffpe_values(vocab, ffpe_val_str='ffpe_unique_values', voc_val_str='def_vocab_values')

# %%
lst_d[0:2] , len(lst_d)
# Out:
# (             0                   1       2                 3     \
#  0  fnac_breast_na  requires follow up  benign  fnac_breast_left
#  1  fnac_breast_na  requires follow up  benign  fnac_breast_left
#
#                                         4               5     6     7     8     \
#  0  negative for atypical or malignant cells  duct carcinoma  None  None  None
#  1  negative for atypical or malignant cells  duct carcinoma  None  None  None
#
#     9     ...  2550  2551  2552  2553  2554  2555  2556  2557  2558  2559
#  0  None  ...  None  None  None  None  None  None  None  None  None  None
#  1  None  ...  None  None  None  None  None  None  None  None  None  None
#
#  [2 rows x 2560 columns],
#  146)
